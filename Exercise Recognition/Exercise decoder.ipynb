# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import tensorflow as tf
import math

from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score, classification_report
from tensorflow.keras.utils import to_categorical

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

from tensorflow.keras.models import Sequential, Model

from tensorflow.keras.layers import (LSTM, Dense, Concatenate, Attention, Dropout, Softmax,
                                     Input, Flatten, Activation, Bidirectional, Permute, multiply, 
                                     ConvLSTM2D, MaxPooling3D, TimeDistributed, Conv2D, MaxPooling2D)

from scipy import stats
# Out:
# WARNING:tensorflow:From C:\Users\lokes\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# disable some of the tf/keras training warnings 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = "3"
tf.get_logger().setLevel("ERROR")
tf.autograph.set_verbosity(1)

# %%
# suppress untraced functions warning
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %%
# Pre-trained pose estimation model from Google Mediapipe
mp_pose = mp.solutions.pose

# %%
# Supported Mediapipe visualization tools
mp_drawing = mp.solutions.drawing_utils

# %%
def mediapipe_detection(image, model):
    """
    This function detects human pose estimation keypoints from webcam footage
    
    """
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    """
    This function draws keypoints and landmarks detected by the human pose estimation model
    
    """
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) 
                                 )

# %%
cap = cv2.VideoCapture(0) # camera object
HEIGHT = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) # webcam video frame height
WIDTH = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) # webcam video frame width
FPS = int(cap.get(cv2.CAP_PROP_FPS)) # webcam video frame rate 

# Set and test mediapipe model using webcam
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()
      
        # Make detection
        image, results = mediapipe_detection(frame, pose)
        
        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
        except:
            pass
        
        # Render detections
        draw_landmarks(image, results)               
        
        # Display frame on screen
        cv2.imshow('OpenCV Feed', image)
        
        # Exit / break out logic
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
# Recollect and organize keypoints from the test
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
# 33 landmarks with 4 values (x, y, z, visibility)
num_landmarks = len(landmarks)
num_values = len(test)
num_input_values = num_landmarks*num_values

# %%
# This is an example of what we would use as an input into our AI models
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)

# %%
def extract_keypoints(results):
    """
    Processes and organizes the keypoints detected from the pose estimation model 
    to be used as inputs for the exercise decoder models
    
    """
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    return pose

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join(os. getcwd(),'data') 
print(DATA_PATH)

# make directory if it does not exist yet
if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH)

# Actions/exercises that we try to detect
actions = np.array(['curl', 'press', 'squat'])
num_classes = len(actions)

# How many videos worth of data
no_sequences = 50

# Videos are going to be this many frames in length
sequence_length = FPS*1

# Folder start
# Change this to collect more data and not lose previously collected data
start_folder = 101
# Out:
# C:\Users\lokes\OneDrive\Desktop\ExerciseDetection\data

# %%
# Build folder paths
for action in actions:     
    for sequence in range(start_folder,no_sequences+start_folder):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))  
        except:
            pass

# %%
# Colors associated with each exercise (e.g., curls are denoted by blue, squats are denoted by orange, etc.)
colors = [(245,117,16), (117,245,16), (16,117,245)]

# %%
# Collect Training Data
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    # Loop through actions
    for idx, action in enumerate(actions):
        # Loop through sequences (i.e., videos)
        for sequence in range(start_folder, start_folder+no_sequences):
            # Loop through video length (i.e, sequence length)
            for frame_num in range(sequence_length):
                # Read feed
                ret, frame = cap.read()
                
                # Make detection
                image, results = mediapipe_detection(frame, pose)

                # Extract landmarks
                try:
                    landmarks = results.pose_landmarks.landmark
                except:
                    pass
                
                # Render detections
                draw_landmarks(image, results) 

                # Apply visualization logic
                if frame_num == 0: # If first frame in sequence, print that you're starting a new data collection and wait 500 ms
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    
                    cv2.putText(image, 'Collecting {} Video # {}'.format(action, sequence), (15,30), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 8, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting {} Video # {}'.format(action, sequence), (15,30), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, colors[idx], 4, cv2.LINE_AA)
                    
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting {} Video # {}'.format(action, sequence), (15,30), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 8, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting {} Video # {}'.format(action, sequence), (15,30), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, colors[idx], 4, cv2.LINE_AA)
                    
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)

                # Export keypoints (sequence + pose landmarks)
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
# Load and organize recorded training data
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):         
            # LSTM input data
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)  
            
        sequences.append(window)
        labels.append(label_map[action])

# %%
# Make sure first dimensions of arrays match
X = np.array(sequences)
y = to_categorical(labels).astype(int)
print(X.shape, y.shape)
# Out:
# (150, 30, 132) (150, 3)

# %%
# Split into training, validation, and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=1)
print(X_train.shape, y_train.shape)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=15/90, random_state=2)
# Out:
# (135, 30, 132) (135, 3)

# %%
# Callbacks to be used during neural network training 
es_callback = EarlyStopping(monitor='val_loss', min_delta=5e-4, patience=30, verbose=0, mode='min')
lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001, verbose=0, mode='min')
chkpt_callback = ModelCheckpoint(filepath=DATA_PATH, monitor='val_loss', verbose=0, save_best_only=True, 
                                 save_weights_only=False, mode='min', save_freq=1)

# Optimizer
opt = tf.keras.optimizers.Adam(learning_rate=0.01)

# some hyperparamters
batch_size = 16
max_epochs = 100

# %%
# Set up Tensorboard logging and callbacks
NAME = f"ExerciseRecognition-LSTM-{int(time.time())}"
log_dir = os.path.join(os.getcwd(), 'logs', NAME,'')
tb_callback = TensorBoard(log_dir=log_dir)

callbacks = [tb_callback, es_callback, lr_callback, chkpt_callback]

# %%
lstm = Sequential()
lstm.add(LSTM(128, return_sequences=True, activation='relu', input_shape=(sequence_length, num_input_values)))
lstm.add(LSTM(256, return_sequences=True, activation='relu'))
lstm.add(LSTM(128, return_sequences=False, activation='relu'))
lstm.add(Dense(128, activation='relu'))
lstm.add(Dense(64, activation='relu'))
lstm.add(Dense(actions.shape[0], activation='softmax'))
print(lstm.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 128)           133632
#
#  lstm_1 (LSTM)               (None, 30, 256)           394240
#
#  lstm_2 (LSTM)               (None, 128)               197120
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 749955 (2.86 MB)
# Trainable params: 749955 (2.86 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
lstm.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
lstm.fit(X_train, y_train, batch_size=batch_size, epochs=max_epochs, validation_data=(X_val, y_val), callbacks=callbacks)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 5s 144ms/step - loss: 420078.6875 - categorical_accuracy: 0.2679 - val_loss: 957236.0625 - val_categorical_accuracy: 0.2609 - lr: 0.0100
# Epoch 2/100
# 7/7 [==============================] - 1s 80ms/step - loss: 169431.3906 - categorical_accuracy: 0.3661 - val_loss: 3822.3750 - val_categorical_accuracy: 0.3913 - lr: 0.0100
# Epoch 3/100
# 7/7 [==============================] - 0s 53ms/step - loss: 1543.7640 - categorical_accuracy: 0.3571 - val_loss: 573.3322 - val_categorical_accuracy: 0.3913 - lr: 0.0100
# Epoch 4/100
# 7/7 [==============================] - 1s 75ms/step - loss: 3419.3540 - categorical_accuracy: 0.3214 - val_loss: 8502.6924 - val_categorical_accuracy: 0.3478 - lr: 0.0100
# Epoch 5/100
# 7/7 [==============================] - 0s 60ms/step - loss: 2890.9783 - categorical_accuracy: 0.2321 - val_loss: 831.1022 - val_categorical_accuracy: 0.3478 - lr: 0.0100
# Epoch 6/100
# 7/7 [==============================] - 0s 56ms/step - loss: 1167.1989 - categorical_accuracy: 0.2768 - val_loss: 1480.0255 - val_categorical_accuracy: 0.3913 - lr: 0.0100
# Epoch 7/100
# 7/7 [==============================] - 0s 56ms/step - loss: 2070.6575 - categorical_accuracy: 0.2232 - val_loss: 1337.1718 - val_categorical_accuracy: 0.2609 - lr: 0.0100
# Epoch 8/100
# 7/7 [==============================] - 0s 57ms/step - loss: 1121.2518 - categorical_accuracy: 0.3393 - val_loss: 299.0384 - val_categorical_accuracy: 0.3913 - lr: 0.0100
# Epoch 9/100
# 7/7 [==============================] - 1s 85ms/step - loss: 400.3293 - categorical_accuracy: 0.2768 - val_loss: 343.5385 - val_categorical_accuracy: 0.3478 - lr: 0.0100
# Epoch 10/100
# 7/7 [==============================] - 0s 60ms/step - loss: 308.0529 - categorical_accuracy: 0.3571 - val_loss: 134.1618 - val_categorical_accuracy: 0.3913 - lr: 0.0100
# Epoch 11/100
# 7/7 [==============================] - 1s 113ms/step - loss: 216.7879 - categorical_accuracy: 0.3214 - val_loss: 268.8271 - val_categorical_accuracy: 0.3913 - lr: 0.0100
# Epoch 12/100
# 7/7 [==============================] - 1s 72ms/step - loss: 436.9747 - categorical_accuracy: 0.2857 - val_loss: 87.3374 - val_categorical_accuracy: 0.2609 - lr: 0.0100
# Epoch 13/100
# 7/7 [==============================] - 1s 75ms/step - loss: 90.4544 - categorical_accuracy: 0.3571 - val_loss: 61.8245 - val_categorical_accuracy: 0.3913 - lr: 0.0100
# Epoch 14/100
# 7/7 [==============================] - 0s 59ms/step - loss: 45.8614 - categorical_accuracy: 0.2857 - val_loss: 32.2797 - val_categorical_accuracy: 0.3913 - lr: 0.0100
# Epoch 15/100
# 7/7 [==============================] - 0s 62ms/step - loss: 73.6959 - categorical_accuracy: 0.3750 - val_loss: 106.8421 - val_categorical_accuracy: 0.3913 - lr: 0.0100
# Epoch 16/100
# 7/7 [==============================] - 0s 65ms/step - loss: 122.0641 - categorical_accuracy: 0.3393 - val_loss: 176.2132 - val_categorical_accuracy: 0.3478 - lr: 0.0100
# Epoch 17/100
# 7/7 [==============================] - 1s 80ms/step - loss: 159.8077 - categorical_accuracy: 0.3036 - val_loss: 76.0924 - val_categorical_accuracy: 0.3478 - lr: 0.0100
# Epoch 18/100
# 7/7 [==============================] - 0s 62ms/step - loss: 76.0922 - categorical_accuracy: 0.3750 - val_loss: 52.4194 - val_categorical_accuracy: 0.3913 - lr: 0.0100
# Epoch 19/100
# 7/7 [==============================] - 1s 82ms/step - loss: 69.3556 - categorical_accuracy: 0.2411 - val_loss: 99.2018 - val_categorical_accuracy: 0.2609 - lr: 0.0100
# Epoch 20/100
# 7/7 [==============================] - 0s 58ms/step - loss: 84.7781 - categorical_accuracy: 0.3036 - val_loss: 75.5200 - val_categorical_accuracy: 0.3478 - lr: 0.0020
# Epoch 21/100
# 7/7 [==============================] - 1s 92ms/step - loss: 36.5907 - categorical_accuracy: 0.3125 - val_loss: 24.8505 - val_categorical_accuracy: 0.3913 - lr: 0.0020
# Epoch 22/100
# 7/7 [==============================] - 1s 98ms/step - loss: 22.0891 - categorical_accuracy: 0.3125 - val_loss: 3.8761 - val_categorical_accuracy: 0.3913 - lr: 0.0020
# Epoch 23/100
# 7/7 [==============================] - 0s 61ms/step - loss: 20.5230 - categorical_accuracy: 0.3750 - val_loss: 20.3501 - val_categorical_accuracy: 0.2609 - lr: 0.0020
# Epoch 24/100
# 7/7 [==============================] - 1s 92ms/step - loss: 14.9336 - categorical_accuracy: 0.4196 - val_loss: 19.8955 - val_categorical_accuracy: 0.3478 - lr: 0.0020
# Epoch 25/100
# 7/7 [==============================] - 1s 74ms/step - loss: 9.4418 - categorical_accuracy: 0.4464 - val_loss: 3.4010 - val_categorical_accuracy: 0.3043 - lr: 0.0020
# Epoch 26/100
# 7/7 [==============================] - 1s 89ms/step - loss: 10.6069 - categorical_accuracy: 0.3393 - val_loss: 3.8848 - val_categorical_accuracy: 0.3043 - lr: 0.0020
# Epoch 27/100
# 7/7 [==============================] - 0s 60ms/step - loss: 12.0405 - categorical_accuracy: 0.3125 - val_loss: 7.9986 - val_categorical_accuracy: 0.3913 - lr: 0.0020
# Epoch 28/100
# 7/7 [==============================] - 1s 96ms/step - loss: 10.6631 - categorical_accuracy: 0.3214 - val_loss: 10.7472 - val_categorical_accuracy: 0.2609 - lr: 0.0020
# Epoch 29/100
# 7/7 [==============================] - 1s 105ms/step - loss: 9.2788 - categorical_accuracy: 0.3929 - val_loss: 18.6836 - val_categorical_accuracy: 0.4348 - lr: 0.0020
# Epoch 30/100
# 7/7 [==============================] - 1s 92ms/step - loss: 15.3466 - categorical_accuracy: 0.3571 - val_loss: 12.7748 - val_categorical_accuracy: 0.2609 - lr: 0.0020
# Epoch 31/100
# 7/7 [==============================] - 1s 103ms/step - loss: 7.1466 - categorical_accuracy: 0.3750 - val_loss: 4.8678 - val_categorical_accuracy: 0.3913 - lr: 4.0000e-04
# Epoch 32/100
# 7/7 [==============================] - 0s 56ms/step - loss: 5.3947 - categorical_accuracy: 0.3214 - val_loss: 4.4456 - val_categorical_accuracy: 0.3478 - lr: 4.0000e-04
# Epoch 33/100
# 7/7 [==============================] - 0s 63ms/step - loss: 3.1784 - categorical_accuracy: 0.3929 - val_loss: 2.5157 - val_categorical_accuracy: 0.3043 - lr: 4.0000e-04
# Epoch 34/100
# 7/7 [==============================] - 0s 59ms/step - loss: 3.1673 - categorical_accuracy: 0.4643 - val_loss: 5.5459 - val_categorical_accuracy: 0.5217 - lr: 4.0000e-04
# Epoch 35/100
# 7/7 [==============================] - 0s 67ms/step - loss: 3.7019 - categorical_accuracy: 0.5179 - val_loss: 1.6358 - val_categorical_accuracy: 0.4783 - lr: 4.0000e-04
# Epoch 36/100
# 7/7 [==============================] - 0s 68ms/step - loss: 2.3920 - categorical_accuracy: 0.4821 - val_loss: 1.8830 - val_categorical_accuracy: 0.3478 - lr: 4.0000e-04
# Epoch 37/100
# 7/7 [==============================] - 0s 54ms/step - loss: 1.8168 - categorical_accuracy: 0.5804 - val_loss: 2.4221 - val_categorical_accuracy: 0.4783 - lr: 4.0000e-04
# Epoch 38/100
# 7/7 [==============================] - 0s 53ms/step - loss: 2.1209 - categorical_accuracy: 0.4911 - val_loss: 1.7747 - val_categorical_accuracy: 0.3478 - lr: 4.0000e-04
# Epoch 39/100
# 7/7 [==============================] - 0s 52ms/step - loss: 2.0978 - categorical_accuracy: 0.3929 - val_loss: 1.7646 - val_categorical_accuracy: 0.4783 - lr: 4.0000e-04
# Epoch 40/100
# 7/7 [==============================] - 0s 56ms/step - loss: 1.5022 - categorical_accuracy: 0.5000 - val_loss: 1.7481 - val_categorical_accuracy: 0.3913 - lr: 4.0000e-04
# Epoch 41/100
# 7/7 [==============================] - 0s 55ms/step - loss: 1.3324 - categorical_accuracy: 0.5089 - val_loss: 1.4871 - val_categorical_accuracy: 0.3043 - lr: 8.0000e-05
# Epoch 42/100
# 7/7 [==============================] - 0s 70ms/step - loss: 1.3781 - categorical_accuracy: 0.5982 - val_loss: 1.6101 - val_categorical_accuracy: 0.4783 - lr: 8.0000e-05
# Epoch 43/100
# 7/7 [==============================] - 0s 69ms/step - loss: 1.3470 - categorical_accuracy: 0.5446 - val_loss: 1.5454 - val_categorical_accuracy: 0.4783 - lr: 8.0000e-05
# Epoch 44/100
# 7/7 [==============================] - 0s 68ms/step - loss: 1.2433 - categorical_accuracy: 0.5893 - val_loss: 1.5463 - val_categorical_accuracy: 0.4783 - lr: 8.0000e-05
# Epoch 45/100
# 7/7 [==============================] - 0s 67ms/step - loss: 1.1780 - categorical_accuracy: 0.6250 - val_loss: 1.4724 - val_categorical_accuracy: 0.4348 - lr: 8.0000e-05
# Epoch 46/100
# 7/7 [==============================] - 0s 66ms/step - loss: 1.1780 - categorical_accuracy: 0.6339 - val_loss: 1.4676 - val_categorical_accuracy: 0.3913 - lr: 8.0000e-05
# Epoch 47/100
# 7/7 [==============================] - 1s 85ms/step - loss: 1.1626 - categorical_accuracy: 0.6429 - val_loss: 1.4988 - val_categorical_accuracy: 0.4348 - lr: 8.0000e-05
# Epoch 48/100
# 7/7 [==============================] - 1s 86ms/step - loss: 1.1848 - categorical_accuracy: 0.6339 - val_loss: 1.4696 - val_categorical_accuracy: 0.4348 - lr: 8.0000e-05
# Epoch 49/100
# 7/7 [==============================] - 1s 86ms/step - loss: 1.2053 - categorical_accuracy: 0.5804 - val_loss: 1.5010 - val_categorical_accuracy: 0.4783 - lr: 8.0000e-05
# Epoch 50/100
# 7/7 [==============================] - 1s 101ms/step - loss: 1.1691 - categorical_accuracy: 0.6339 - val_loss: 1.4908 - val_categorical_accuracy: 0.4783 - lr: 8.0000e-05
# Epoch 51/100
# 7/7 [==============================] - 1s 73ms/step - loss: 1.1767 - categorical_accuracy: 0.6071 - val_loss: 1.4807 - val_categorical_accuracy: 0.4783 - lr: 8.0000e-05
# Epoch 52/100
# 7/7 [==============================] - 1s 106ms/step - loss: 1.1542 - categorical_accuracy: 0.6429 - val_loss: 1.5052 - val_categorical_accuracy: 0.4783 - lr: 1.6000e-05
# Epoch 53/100
# 7/7 [==============================] - 1s 79ms/step - loss: 1.1586 - categorical_accuracy: 0.6518 - val_loss: 1.4892 - val_categorical_accuracy: 0.4783 - lr: 1.6000e-05
# Epoch 54/100
# 7/7 [==============================] - 1s 87ms/step - loss: 1.1531 - categorical_accuracy: 0.6429 - val_loss: 1.4879 - val_categorical_accuracy: 0.4783 - lr: 1.6000e-05
# Epoch 55/100
# 7/7 [==============================] - 1s 90ms/step - loss: 1.1514 - categorical_accuracy: 0.6429 - val_loss: 1.4750 - val_categorical_accuracy: 0.3478 - lr: 1.6000e-05
# Epoch 56/100
# 7/7 [==============================] - 1s 95ms/step - loss: 1.1520 - categorical_accuracy: 0.6429 - val_loss: 1.4721 - val_categorical_accuracy: 0.3478 - lr: 1.6000e-05
# Epoch 57/100
# 7/7 [==============================] - 1s 106ms/step - loss: 1.1598 - categorical_accuracy: 0.6429 - val_loss: 1.4653 - val_categorical_accuracy: 0.4348 - lr: 1.0000e-05
# Epoch 58/100
# 7/7 [==============================] - 1s 92ms/step - loss: 1.1596 - categorical_accuracy: 0.6518 - val_loss: 1.4686 - val_categorical_accuracy: 0.3913 - lr: 1.0000e-05
# Epoch 59/100
# 7/7 [==============================] - 1s 106ms/step - loss: 1.1609 - categorical_accuracy: 0.6429 - val_loss: 1.5058 - val_categorical_accuracy: 0.5217 - lr: 1.0000e-05
# Epoch 60/100
# 7/7 [==============================] - 1s 123ms/step - loss: 1.1639 - categorical_accuracy: 0.6429 - val_loss: 1.4772 - val_categorical_accuracy: 0.3478 - lr: 1.0000e-05
# Epoch 61/100
# 7/7 [==============================] - 1s 115ms/step - loss: 1.1516 - categorical_accuracy: 0.6429 - val_loss: 1.4799 - val_categorical_accuracy: 0.4348 - lr: 1.0000e-05
# Epoch 62/100
# 7/7 [==============================] - 1s 105ms/step - loss: 1.1522 - categorical_accuracy: 0.6429 - val_loss: 1.4741 - val_categorical_accuracy: 0.3478 - lr: 1.0000e-05
# Epoch 63/100
# 7/7 [==============================] - 1s 91ms/step - loss: 1.1528 - categorical_accuracy: 0.6518 - val_loss: 1.4735 - val_categorical_accuracy: 0.3913 - lr: 1.0000e-05
# Epoch 64/100
# 7/7 [==============================] - 0s 66ms/step - loss: 1.1530 - categorical_accuracy: 0.6518 - val_loss: 1.4709 - val_categorical_accuracy: 0.4348 - lr: 1.0000e-05
# Epoch 65/100
# 7/7 [==============================] - 1s 93ms/step - loss: 1.1602 - categorical_accuracy: 0.6607 - val_loss: 1.4974 - val_categorical_accuracy: 0.5217 - lr: 1.0000e-05
# Epoch 66/100
# 7/7 [==============================] - 1s 104ms/step - loss: 1.1575 - categorical_accuracy: 0.6518 - val_loss: 1.4754 - val_categorical_accuracy: 0.3913 - lr: 1.0000e-05
# Epoch 67/100
# 7/7 [==============================] - 0s 76ms/step - loss: 1.1521 - categorical_accuracy: 0.6518 - val_loss: 1.4757 - val_categorical_accuracy: 0.3913 - lr: 1.0000e-05
# Epoch 68/100
# 7/7 [==============================] - 1s 113ms/step - loss: 1.1566 - categorical_accuracy: 0.6518 - val_loss: 1.4704 - val_categorical_accuracy: 0.4348 - lr: 1.0000e-05
# Epoch 69/100
# 7/7 [==============================] - 1s 78ms/step - loss: 1.1544 - categorical_accuracy: 0.6339 - val_loss: 1.4912 - val_categorical_accuracy: 0.4783 - lr: 1.0000e-05
# Epoch 70/100
# 7/7 [==============================] - 0s 67ms/step - loss: 1.1531 - categorical_accuracy: 0.6607 - val_loss: 1.4815 - val_categorical_accuracy: 0.4348 - lr: 1.0000e-05
# Epoch 71/100
# 7/7 [==============================] - 0s 62ms/step - loss: 1.1553 - categorical_accuracy: 0.6429 - val_loss: 1.4689 - val_categorical_accuracy: 0.3913 - lr: 1.0000e-05
# Epoch 72/100
# 7/7 [==============================] - 1s 75ms/step - loss: 1.1508 - categorical_accuracy: 0.6339 - val_loss: 1.4777 - val_categorical_accuracy: 0.4348 - lr: 1.0000e-05
# Epoch 73/100
# 7/7 [==============================] - 0s 73ms/step - loss: 1.1538 - categorical_accuracy: 0.6339 - val_loss: 1.4802 - val_categorical_accuracy: 0.4348 - lr: 1.0000e-05
# Epoch 74/100
# 7/7 [==============================] - 1s 73ms/step - loss: 1.1536 - categorical_accuracy: 0.6429 - val_loss: 1.4701 - val_categorical_accuracy: 0.3913 - lr: 1.0000e-05
# Epoch 75/100
# 7/7 [==============================] - 0s 70ms/step - loss: 1.1504 - categorical_accuracy: 0.6518 - val_loss: 1.4722 - val_categorical_accuracy: 0.4348 - lr: 1.0000e-05
# Epoch 76/100
# 7/7 [==============================] - 0s 71ms/step - loss: 1.1580 - categorical_accuracy: 0.6518 - val_loss: 1.4816 - val_categorical_accuracy: 0.4783 - lr: 1.0000e-05
# Epoch 77/100
# 7/7 [==============================] - 0s 64ms/step - loss: 1.1524 - categorical_accuracy: 0.6518 - val_loss: 1.4832 - val_categorical_accuracy: 0.4783 - lr: 1.0000e-05
# Epoch 78/100
# 7/7 [==============================] - 0s 74ms/step - loss: 1.1523 - categorical_accuracy: 0.6518 - val_loss: 1.4724 - val_categorical_accuracy: 0.4348 - lr: 1.0000e-05
# Epoch 79/100
# 7/7 [==============================] - 0s 61ms/step - loss: 1.1523 - categorical_accuracy: 0.6518 - val_loss: 1.4771 - val_categorical_accuracy: 0.3913 - lr: 1.0000e-05
# Epoch 80/100
# 7/7 [==============================] - 0s 67ms/step - loss: 1.1528 - categorical_accuracy: 0.6518 - val_loss: 1.4739 - val_categorical_accuracy: 0.3913 - lr: 1.0000e-05
# Epoch 81/100
# 7/7 [==============================] - 1s 73ms/step - loss: 1.1534 - categorical_accuracy: 0.6429 - val_loss: 1.4769 - val_categorical_accuracy: 0.4348 - lr: 1.0000e-05
# Epoch 82/100
# 7/7 [==============================] - 1s 91ms/step - loss: 1.1562 - categorical_accuracy: 0.6429 - val_loss: 1.5013 - val_categorical_accuracy: 0.5217 - lr: 1.0000e-05
# Epoch 83/100
# 7/7 [==============================] - 1s 79ms/step - loss: 1.1522 - categorical_accuracy: 0.6607 - val_loss: 1.4739 - val_categorical_accuracy: 0.3913 - lr: 1.0000e-05
# Epoch 84/100
# 7/7 [==============================] - 0s 65ms/step - loss: 1.1500 - categorical_accuracy: 0.6429 - val_loss: 1.4685 - val_categorical_accuracy: 0.4783 - lr: 1.0000e-05
# Epoch 85/100
# 7/7 [==============================] - 1s 81ms/step - loss: 1.1585 - categorical_accuracy: 0.6429 - val_loss: 1.4777 - val_categorical_accuracy: 0.4348 - lr: 1.0000e-05
# Epoch 86/100
# 7/7 [==============================] - 1s 74ms/step - loss: 1.1590 - categorical_accuracy: 0.6429 - val_loss: 1.4814 - val_categorical_accuracy: 0.4348 - lr: 1.0000e-05
# Epoch 87/100
# 7/7 [==============================] - 0s 66ms/step - loss: 1.1539 - categorical_accuracy: 0.6696 - val_loss: 1.4750 - val_categorical_accuracy: 0.3913 - lr: 1.0000e-05

# %%
# Set up Tensorboard logging and callbacks
NAME = f"ExerciseRecognition-AttnLSTM-{int(time.time())}"
log_dir = os.path.join(os.getcwd(), 'logs', NAME,'')
tb_callback = TensorBoard(log_dir=log_dir)

callbacks = [tb_callback, es_callback, lr_callback, chkpt_callback]

# %%
def attention_block(inputs, time_steps):
    """
    Attention layer for deep neural network
    
    """
    # Attention weights
    a = Permute((2, 1))(inputs)
    a = Dense(time_steps, activation='softmax')(a)
    
    # Attention vector
    a_probs = Permute((2, 1), name='attention_vec')(a)
    
    # Luong's multiplicative score
    output_attention_mul = multiply([inputs, a_probs], name='attention_mul') 
    
    return output_attention_mul

# %%
HIDDEN_UNITS = 256

# Input
inputs = Input(shape=(sequence_length, num_input_values))

# Bi-LSTM
lstm_out = Bidirectional(LSTM(HIDDEN_UNITS, return_sequences=True))(inputs)

# Attention
attention_mul = attention_block(lstm_out, sequence_length)
attention_mul = Flatten()(attention_mul)

# Fully Connected Layer
x = Dense(2*HIDDEN_UNITS, activation='relu')(attention_mul)
x = Dropout(0.5)(x)

# Output
x = Dense(actions.shape[0], activation='softmax')(x)

# Bring it all together
AttnLSTM = Model(inputs=[inputs], outputs=x)
print(AttnLSTM.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 30, 132)]            0         []
#
#  bidirectional (Bidirection  (None, 30, 512)              796672    ['input_1[0][0]']
#  al)
#
#  permute (Permute)           (None, 512, 30)              0         ['bidirectional[0][0]']
#
#  dense_3 (Dense)             (None, 512, 30)              930       ['permute[0][0]']
#
#  attention_vec (Permute)     (None, 30, 512)              0         ['dense_3[0][0]']
#
#  attention_mul (Multiply)    (None, 30, 512)              0         ['bidirectional[0][0]',
#                                                                      'attention_vec[0][0]']
#
#  flatten (Flatten)           (None, 15360)                0         ['attention_mul[0][0]']
#
#  dense_4 (Dense)             (None, 512)                  7864832   ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 512)                  0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 3)                    1539      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 8663973 (33.05 MB)
# Trainable params: 8663973 (33.05 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %%
# Import the legacy optimizer
from tensorflow.keras.optimizers import RMSprop

# Define your optimizer
opt = RMSprop(learning_rate=0.001)

# Build the optimizer with all trainable variables
opt.build(AttnLSTM.trainable_variables)

# Compile your model
AttnLSTM.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# Fit the model to your training data
AttnLSTM.fit(X_train, y_train, batch_size=batch_size, epochs=max_epochs, validation_data=(X_val, y_val), callbacks=callbacks)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 5s 238ms/step - loss: 1.0420 - categorical_accuracy: 0.4643 - val_loss: 0.8599 - val_categorical_accuracy: 0.5652 - lr: 0.0010
# Epoch 2/100
# 7/7 [==============================] - 1s 87ms/step - loss: 0.7991 - categorical_accuracy: 0.6429 - val_loss: 0.6586 - val_categorical_accuracy: 0.8261 - lr: 0.0010
# Epoch 3/100
# 7/7 [==============================] - 1s 98ms/step - loss: 0.7148 - categorical_accuracy: 0.6875 - val_loss: 1.1135 - val_categorical_accuracy: 0.3913 - lr: 0.0010
# Epoch 4/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.5809 - categorical_accuracy: 0.7768 - val_loss: 0.4790 - val_categorical_accuracy: 0.8261 - lr: 0.0010
# Epoch 5/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.4889 - categorical_accuracy: 0.7946 - val_loss: 0.5876 - val_categorical_accuracy: 0.7826 - lr: 0.0010
# Epoch 6/100
# 7/7 [==============================] - 1s 98ms/step - loss: 0.4683 - categorical_accuracy: 0.8214 - val_loss: 0.4494 - val_categorical_accuracy: 0.8696 - lr: 0.0010
# Epoch 7/100
# 7/7 [==============================] - 1s 106ms/step - loss: 0.3220 - categorical_accuracy: 0.8661 - val_loss: 0.4577 - val_categorical_accuracy: 0.8696 - lr: 0.0010
# Epoch 8/100
# 7/7 [==============================] - 1s 102ms/step - loss: 0.3291 - categorical_accuracy: 0.8571 - val_loss: 0.5969 - val_categorical_accuracy: 0.8261 - lr: 0.0010
# Epoch 9/100
# 7/7 [==============================] - 1s 106ms/step - loss: 0.4144 - categorical_accuracy: 0.8304 - val_loss: 0.7133 - val_categorical_accuracy: 0.6957 - lr: 0.0010
# Epoch 10/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.3693 - categorical_accuracy: 0.8482 - val_loss: 0.4908 - val_categorical_accuracy: 0.8696 - lr: 0.0010
# Epoch 11/100
# 7/7 [==============================] - 1s 100ms/step - loss: 0.1847 - categorical_accuracy: 0.9554 - val_loss: 0.6371 - val_categorical_accuracy: 0.8261 - lr: 0.0010
# Epoch 12/100
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1959 - categorical_accuracy: 0.9196 - val_loss: 0.5361 - val_categorical_accuracy: 0.8696 - lr: 2.0000e-04
# Epoch 13/100
# 7/7 [==============================] - 1s 119ms/step - loss: 0.1552 - categorical_accuracy: 0.9375 - val_loss: 0.5416 - val_categorical_accuracy: 0.8696 - lr: 2.0000e-04
# Epoch 14/100
# 7/7 [==============================] - 1s 123ms/step - loss: 0.1526 - categorical_accuracy: 0.9554 - val_loss: 0.5777 - val_categorical_accuracy: 0.8696 - lr: 2.0000e-04
# Epoch 15/100
# 7/7 [==============================] - 1s 124ms/step - loss: 0.1302 - categorical_accuracy: 0.9643 - val_loss: 0.6003 - val_categorical_accuracy: 0.8696 - lr: 2.0000e-04
# Epoch 16/100
# 7/7 [==============================] - 1s 117ms/step - loss: 0.1315 - categorical_accuracy: 0.9464 - val_loss: 0.6021 - val_categorical_accuracy: 0.8696 - lr: 2.0000e-04
# Epoch 17/100
# 7/7 [==============================] - 1s 120ms/step - loss: 0.1149 - categorical_accuracy: 0.9643 - val_loss: 0.6062 - val_categorical_accuracy: 0.8696 - lr: 4.0000e-05
# Epoch 18/100
# 7/7 [==============================] - 1s 117ms/step - loss: 0.1045 - categorical_accuracy: 0.9554 - val_loss: 0.6101 - val_categorical_accuracy: 0.8696 - lr: 4.0000e-05
# Epoch 19/100
# 7/7 [==============================] - 1s 112ms/step - loss: 0.0941 - categorical_accuracy: 0.9643 - val_loss: 0.6126 - val_categorical_accuracy: 0.8696 - lr: 4.0000e-05
# Epoch 20/100
# 7/7 [==============================] - 1s 120ms/step - loss: 0.1031 - categorical_accuracy: 0.9643 - val_loss: 0.6177 - val_categorical_accuracy: 0.8696 - lr: 4.0000e-05
# Epoch 21/100
# 7/7 [==============================] - 1s 116ms/step - loss: 0.0891 - categorical_accuracy: 0.9821 - val_loss: 0.6213 - val_categorical_accuracy: 0.8696 - lr: 4.0000e-05
# Epoch 22/100
# 7/7 [==============================] - 1s 108ms/step - loss: 0.1055 - categorical_accuracy: 0.9732 - val_loss: 0.6226 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 23/100
# 7/7 [==============================] - 1s 120ms/step - loss: 0.0954 - categorical_accuracy: 0.9732 - val_loss: 0.6236 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 24/100
# 7/7 [==============================] - 1s 132ms/step - loss: 0.0847 - categorical_accuracy: 0.9821 - val_loss: 0.6246 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 25/100
# 7/7 [==============================] - 1s 132ms/step - loss: 0.0945 - categorical_accuracy: 0.9643 - val_loss: 0.6259 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 26/100
# 7/7 [==============================] - 1s 105ms/step - loss: 0.0852 - categorical_accuracy: 0.9821 - val_loss: 0.6268 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 27/100
# 7/7 [==============================] - 1s 94ms/step - loss: 0.0942 - categorical_accuracy: 0.9643 - val_loss: 0.6281 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 28/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0953 - categorical_accuracy: 0.9643 - val_loss: 0.6291 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 29/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0956 - categorical_accuracy: 0.9732 - val_loss: 0.6301 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 30/100
# 7/7 [==============================] - 1s 92ms/step - loss: 0.1005 - categorical_accuracy: 0.9732 - val_loss: 0.6313 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 31/100
# 7/7 [==============================] - 1s 93ms/step - loss: 0.0913 - categorical_accuracy: 0.9732 - val_loss: 0.6322 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 32/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0915 - categorical_accuracy: 0.9554 - val_loss: 0.6334 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 33/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0816 - categorical_accuracy: 0.9732 - val_loss: 0.6349 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 34/100
# 7/7 [==============================] - 1s 91ms/step - loss: 0.0876 - categorical_accuracy: 0.9732 - val_loss: 0.6363 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 35/100
# 7/7 [==============================] - 1s 95ms/step - loss: 0.0839 - categorical_accuracy: 0.9732 - val_loss: 0.6374 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05
# Epoch 36/100
# 7/7 [==============================] - 1s 102ms/step - loss: 0.0912 - categorical_accuracy: 0.9732 - val_loss: 0.6387 - val_categorical_accuracy: 0.8696 - lr: 1.0000e-05

# %%
# Model map
models = {
    'LSTM': lstm, 
    'LSTM_Attention_128HUs': AttnLSTM, 
}

# %%
for model_name, model in models.items():
    save_dir = os.path.join(os.getcwd(), f"{model_name}.h5")
    model.save(save_dir)
# Out:
# C:\Users\lokes\anaconda3\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Run model rebuild before doing this
for model_name, model in models.items():
    load_dir = os.path.join(os.getcwd(), f"{model_name}.h5")
    model.load_weights(load_dir)

# %%
for model in models.values():
    res = model.predict(X_test, verbose=0)

# %%
eval_results = {}
eval_results['confusion matrix'] = None
eval_results['accuracy'] = None
eval_results['precision'] = None
eval_results['recall'] = None
eval_results['f1 score'] = None

confusion_matrices = {}
classification_accuracies = {}   
precisions = {}
recalls = {}
f1_scores = {}

# %%
for model_name, model in models.items():
    yhat = model.predict(X_test, verbose=0)
    
    # Get list of classification predictions
    ytrue = np.argmax(y_test, axis=1).tolist()
    yhat = np.argmax(yhat, axis=1).tolist()
    
    # Confusion matrix
    confusion_matrices[model_name] = multilabel_confusion_matrix(ytrue, yhat)
    print(f"{model_name} confusion matrix: {os.linesep}{confusion_matrices[model_name]}")

# Collect results 
eval_results['confusion matrix'] = confusion_matrices
# Out:
# LSTM confusion matrix:
# [[[9 1]
#   [3 2]]
#
#  [[7 2]
#   [4 2]]
#
#  [[6 5]
#   [1 3]]]
# LSTM_Attention_128HUs confusion matrix:
# [[[10  0]
#   [ 1  4]]
#
#  [[ 8  1]
#   [ 1  5]]
#
#  [[10  1]
#   [ 0  4]]]

# %%
for model_name, model in models.items():
    yhat = model.predict(X_test, verbose=0)
    
    # Get list of classification predictions
    ytrue = np.argmax(y_test, axis=1).tolist()
    yhat = np.argmax(yhat, axis=1).tolist()
    
    # Model accuracy
    classification_accuracies[model_name] = accuracy_score(ytrue, yhat)    
    print(f"{model_name} classification accuracy = {round(classification_accuracies[model_name]*100,3)}%")

# Collect results 
eval_results['accuracy'] = classification_accuracies
# Out:
# LSTM classification accuracy = 46.667%
# LSTM_Attention_128HUs classification accuracy = 86.667%

# %%
for model_name, model in models.items():
    yhat = model.predict(X_test, verbose=0)
    
    # Get list of classification predictions
    ytrue = np.argmax(y_test, axis=1).tolist()
    yhat = np.argmax(yhat, axis=1).tolist()
    
    # Precision, recall, and f1 score
    report = classification_report(ytrue, yhat, target_names=actions, output_dict=True)
    
    precisions[model_name] = report['weighted avg']['precision']
    recalls[model_name] = report['weighted avg']['recall']
    f1_scores[model_name] = report['weighted avg']['f1-score'] 
   
    print(f"{model_name} weighted average precision = {round(precisions[model_name],3)}")
    print(f"{model_name} weighted average recall = {round(recalls[model_name],3)}")
    print(f"{model_name} weighted average f1-score = {round(f1_scores[model_name],3)}\n")

# Collect results 
eval_results['precision'] = precisions
eval_results['recall'] = recalls
eval_results['f1 score'] = f1_scores
# Out:
# LSTM weighted average precision = 0.522
# LSTM weighted average recall = 0.467
# LSTM weighted average f1-score = 0.46
#
# LSTM_Attention_128HUs weighted average precision = 0.88
# LSTM_Attention_128HUs weighted average recall = 0.867
# LSTM_Attention_128HUs weighted average f1-score = 0.867

# %%
model = AttnLSTM
model_name = 'AttnLSTM'

# %%
def calculate_angle(a,b,c):
    """
    Computes 3D joint angle inferred by 3 keypoints and their relative positions to one another
    
    """
    a = np.array(a) # First
    b = np.array(b) # Mid
    c = np.array(c) # End
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle >180.0:
        angle = 360-angle
        
    return angle

# %%
def get_coordinates(landmarks, mp_pose, side, joint):
    """
    Retrieves x and y coordinates of a particular keypoint from the pose estimation model
         
     Args:
         landmarks: processed keypoints from the pose estimation model
         mp_pose: Mediapipe pose estimation model
         side: 'left' or 'right'. Denotes the side of the body of the landmark of interest.
         joint: 'shoulder', 'elbow', 'wrist', 'hip', 'knee', or 'ankle'. Denotes which body joint is associated with the landmark of interest.
    
    """
    coord = getattr(mp_pose.PoseLandmark,side.upper()+"_"+joint.upper())
    x_coord_val = landmarks[coord.value].x
    y_coord_val = landmarks[coord.value].y
    return [x_coord_val, y_coord_val]

# %%
def viz_joint_angle(image, angle, joint):
    """
    Displays the joint angle value near the joint within the image frame
    
    """
    cv2.putText(image, str(int(angle)), 
                   tuple(np.multiply(joint, [640, 480]).astype(int)), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA
                        )
    return

# %%
def count_reps(image, current_action, landmarks, mp_pose):
    """
    Counts repetitions of each exercise. Global count and stage (i.e., state) variables are updated within this function.
    
    """

    global curl_counter, press_counter, squat_counter, curl_stage, press_stage, squat_stage
    
    if current_action == 'curl':
        # Get coords
        shoulder = get_coordinates(landmarks, mp_pose, 'left', 'shoulder')
        elbow = get_coordinates(landmarks, mp_pose, 'left', 'elbow')
        wrist = get_coordinates(landmarks, mp_pose, 'left', 'wrist')
        
        # calculate elbow angle
        angle = calculate_angle(shoulder, elbow, wrist)
        
        # curl counter logic
        if angle < 30:
            curl_stage = "up" 
        if angle > 140 and curl_stage =='up':
            curl_stage="down"  
            curl_counter +=1
        press_stage = None
        squat_stage = None
            
        # Viz joint angle
        viz_joint_angle(image, angle, elbow)
        
    elif current_action == 'press':
        
        # Get coords
        shoulder = get_coordinates(landmarks, mp_pose, 'left', 'shoulder')
        elbow = get_coordinates(landmarks, mp_pose, 'left', 'elbow')
        wrist = get_coordinates(landmarks, mp_pose, 'left', 'wrist')

        # Calculate elbow angle
        elbow_angle = calculate_angle(shoulder, elbow, wrist)
        
        # Compute distances between joints
        shoulder2elbow_dist = abs(math.dist(shoulder,elbow))
        shoulder2wrist_dist = abs(math.dist(shoulder,wrist))
        
        # Press counter logic
        if (elbow_angle > 130) and (shoulder2elbow_dist < shoulder2wrist_dist):
            press_stage = "up"
        if (elbow_angle < 50) and (shoulder2elbow_dist > shoulder2wrist_dist) and (press_stage =='up'):
            press_stage='down'
            press_counter += 1
        curl_stage = None
        squat_stage = None
            
        # Viz joint angle
        viz_joint_angle(image, elbow_angle, elbow)
        
    elif current_action == 'squat':
        # Get coords
        # left side
        left_shoulder = get_coordinates(landmarks, mp_pose, 'left', 'shoulder')
        left_hip = get_coordinates(landmarks, mp_pose, 'left', 'hip')
        left_knee = get_coordinates(landmarks, mp_pose, 'left', 'knee')
        left_ankle = get_coordinates(landmarks, mp_pose, 'left', 'ankle')
        # right side
        right_shoulder = get_coordinates(landmarks, mp_pose, 'right', 'shoulder')
        right_hip = get_coordinates(landmarks, mp_pose, 'right', 'hip')
        right_knee = get_coordinates(landmarks, mp_pose, 'right', 'knee')
        right_ankle = get_coordinates(landmarks, mp_pose, 'right', 'ankle')
        
        # Calculate knee angles
        left_knee_angle = calculate_angle(left_hip, left_knee, left_ankle)
        right_knee_angle = calculate_angle(right_hip, right_knee, right_ankle)
        
        # Calculate hip angles
        left_hip_angle = calculate_angle(left_shoulder, left_hip, left_knee)
        right_hip_angle = calculate_angle(right_shoulder, right_hip, right_knee)
        
        # Squat counter logic
        thr = 165
        if (left_knee_angle < thr) and (right_knee_angle < thr) and (left_hip_angle < thr) and (right_hip_angle < thr):
            squat_stage = "down"
        if (left_knee_angle > thr) and (right_knee_angle > thr) and (left_hip_angle > thr) and (right_hip_angle > thr) and (squat_stage =='down'):
            squat_stage='up'
            squat_counter += 1
        curl_stage = None
        press_stage = None
            
        # Viz joint angles
        viz_joint_angle(image, left_knee_angle, left_knee)
        viz_joint_angle(image, left_hip_angle, left_hip)
        
    else:
        pass

# %%
def prob_viz(res, actions, input_frame, colors):
    """
    This function displays the model prediction probability distribution over the set of exercise classes
    as a horizontal bar graph
    
    """
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):        
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
predictions = []
res = []
threshold = 0.5 # minimum confidence to classify as an action/exercise
current_action = ''

# Rep counter logic variables
curl_counter = 0
press_counter = 0
squat_counter = 0
curl_stage = None
press_stage = None
squat_stage = None

# Camera object
cap = cv2.VideoCapture(0)

# Video writer object that saves a video of the real time test
fourcc = cv2.VideoWriter_fourcc('M','J','P','G') # video compression format
HEIGHT = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) # webcam video frame height
WIDTH = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) # webcam video frame width
FPS = int(cap.get(cv2.CAP_PROP_FPS)) # webcam video fram rate 

video_name = os.path.join(os.getcwd(),f"{model_name}_real_time_test.avi")
out = cv2.VideoWriter(video_name, cv2.VideoWriter_fourcc(*"MJPG"), FPS, (WIDTH,HEIGHT))

# Set mediapipe model 
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detection
        image, results = mediapipe_detection(frame, pose)
        
        # Draw landmarks
        draw_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)        
        sequence.append(keypoints)      
        sequence = sequence[-sequence_length:]
              
        if len(sequence) == sequence_length:
            res = model.predict(np.expand_dims(sequence, axis=0), verbose=0)[0]           
            predictions.append(np.argmax(res))
            current_action = actions[np.argmax(res)]
            confidence = np.max(res)
            
        #3. Viz logic
            # Erase current action variable if no probability is above threshold
            if confidence < threshold:
                current_action = ''

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
            # Count reps
            try:
                landmarks = results.pose_landmarks.landmark
                count_reps(
                    image, current_action, landmarks, mp_pose)
            except:
                pass
            # Display graphical information
            cv2.rectangle(image, (0,0), (640, 40), colors[np.argmax(res)], -1)
            cv2.putText(image, 'curl ' + str(curl_counter), (3,30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(image, 'press ' + str(press_counter), (240,30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(image, 'squat ' + str(squat_counter), (490,30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
         
        # Show to screen
        cv2.imshow('OpenCV Feed', image)
        
        # Write to video file
        if ret == True:
            out.write(image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    out.release()
    cv2.destroyAllWindows()

# %%
cap.release()
out.release()
cv2.destroyAllWindows()
